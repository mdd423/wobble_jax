# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.table as at

import loss as wobble_loss
import simulator as wobble_sim
import model as wobble_model
import dataset as wobble_data
import jax.numpy as jnp

# %%
tbl = at.QTable.read('data/hat-p-20.fits')
dataset = wobble_data.AstroDataset(tbl['flux'],tbl['wavelength'],tbl['mask'],tbl['flux_err'])
dataset.interpolate_mask()
dataset.gauss_filter(sigma=80.)
x, y, y_err = dataset.get_xy(subset=(1800,2000))

x_shifts = wobble_data.getInitXShift(tbl['BJD'],'HAT-P-20','APO')

num_params = 100
loss_1 = wobble_model.LossFunc('L2Loss')
# loss_2 = 0.001 * wobble_model.LossFunc('L2Reg')
# loss   = loss_1 + loss_2
model  = wobble_model.JnpLin(num_params,y,x,x_shifts)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
import cProfile

# %%
model.optimize(loss_1)
model.plot()
plt.show()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 123.832664
#          Iterations: 104
#          Function evaluations: 193
#          Gradient evaluations: 181

# %%
num_params = 100
loss_1 = wobble_model.LossFunc('L2Loss')
model  = wobble_model.FourierModel(num_params,y,x,x_shifts)

# %%
model.optimize(loss_1)
model.plot()
plt.show()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 170.322266
#          Iterations: 0
#          Function evaluations: 61
#          Gradient evaluations: 49
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-761ff8388eb1> in <module>
#       1 model.optimize(loss_1)
# ----> 2 model.plot()
#       3 plt.show()
#
# ~/Documents/pythons/wobble_toys/repos/wobble_jax/model.py in plot(self, noise, env, atm_model)
#     143
#     144             if atm_model is not None:
# --> 145                 plt.plot(atm_model.x - atm_model.shifted[i],atm_model.params,'.g',linestyle='solid',linewidth=.8,zorder=2,alpha=0.5,ms=6)
#     146
#     147             self.plot_model(i)
#
# TypeError: plot_model() takes 1 positional argument but 2 were given

# %%
print(x[0,0],x[0,-1],np.floor((x[0,0] - x[0,-1])/1.5e-5))
# Out:
# 9.713292 9.710223 204.0
