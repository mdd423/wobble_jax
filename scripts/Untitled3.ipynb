# %%
loss = [196.9,188.025,187.15,186.71,185.33,185.05,184.30,184.1,182.72]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(loss,'*r')
plt.xlabel('iteration in round 2')
plt.ylabel('loss eval over all epochs')
# plt.show()
plt.savefig('out/rd2loss.png')
